# %% [markdown]
# <a href="https://colab.research.google.com/github/julienessan/Projet_Data_Science/blob/main/Test1python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Bienvenue")
# Out:
# Bienvenue
